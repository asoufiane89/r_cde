# %%
#### creating an R code just for github purpose

library(data.table)
test<- fread("/home/ubuntu/data/input_data.csv")
# Out:
#       search_date gl_product_group total_first_search_max
# 1     2017-07-09   14              256566
# 2     2017-07-09   15               36113
# 3     2017-07-09   21              212232
# 4     2017-07-09   23               89524
# 5     2017-07-09   27                 348
# 6     2017-07-09   60              200316
# 7     2017-07-09   63               75962
# 8     2017-07-09   65                6369
# 9     2017-07-09   74               80580
# 10    2017-07-09   75               68894
# 11    2017-07-09   79               82438
# 12    2017-07-09   86              188146
# 13    2017-07-09  107              233810
# 14    2017-07-09  121              134714
# 15    2017-07-09  129                3790
# 16    2017-07-09  147              158844
# 17    2017-07-09  153                 190
# 18    2017-07-09  193              239518
# 19    2017-07-09  194              100233
# 20    2017-07-09  195                   3
# 21    2017-07-09  196               86438
# ...
